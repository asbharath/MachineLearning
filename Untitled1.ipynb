# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
a = np.random.random(10)
b = np.random.randn(10)

# %%
np.corrcoef(a,b)
# Out:
# array([[1.        , 0.01015192],
#        [0.01015192, 1.        ]])

# %%
np.corrcoef(b)
# Out:
# 1.0

# %%
a[1:]
# Out:
# array([0.64934468, 0.78157662, 0.40949763, 0.15477312, 0.88856353,
#        0.26317219, 0.19577133, 0.60495378, 0.44537991])

# %%
a[:-1]
# Out:
# array([0.86453418, 0.64934468, 0.78157662, 0.40949763, 0.15477312,
#        0.88856353, 0.26317219, 0.19577133, 0.60495378])

# %%
lag = a[1:] - a[:-1]
plt.plot(lag)

# %%
np.corrcoef(a[1:],a[:-1])
# Out:
# array([[ 1.        , -0.14338922],
#        [-0.14338922,  1.        ]])

# %%
import statsmodels.tsa.stattools as tsa
import statsmodels.graphics.tsaplots as tsplot

# %%
a = np.random.randn(100).cumsum()

# %%
plt.plot(a)

# %%
lag = a[2:] - a[:-2]

# %%
plt.plot(tsa.acf(lag))
# Out:
# C:\Users\bhara\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:541: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(msg, FutureWarning)

# %%
tsplot.plot_acf(lag)

# %%
plt.plot(lag)

# %%
noise = np.random.randn(1000)

# %%
ma2=[]
for i in range(3,1000):
    ma2.append(noise[i]+0.7*noise[i-1]+0.2*noise[i-2])

# %%
fig,ax = plt.subplots(2,0)
plt.plot(ma2)

# %%
tsplot.plot_acf(tsa.acf(ma2))

# %%
import pandas as pd

# TODO: Set weight1, weight2, and bias
weight1 = 10000
weight2 = 200
bias = -1000


# DON'T CHANGE ANYTHING BELOW
# Inputs and outputs
test_inputs = [(0, 0), (0, 1), (1, 0), (1, 1)]
correct_outputs = [False, False, False, True]
outputs = []

# Generate and check output
for test_input, correct_output in zip(test_inputs, correct_outputs):
    linear_combination = weight1 * test_input[0] + weight2 * test_input[1] + bias
    output = int(linear_combination >= 0)
    is_correct_string = 'Yes' if output == correct_output else 'No'
    outputs.append([test_input[0], test_input[1], linear_combination, output, is_correct_string])

# Print output
num_wrong = len([output[4] for output in outputs if output[4] == 'No'])
output_frame = pd.DataFrame(outputs, columns=['Input 1', '  Input 2', '  Linear Combination', '  Activation Output', '  Is Correct'])
if not num_wrong:
    print('Nice!  You got it all correct.\n')
else:
    print('You got {} wrong.  Keep trying!\n'.format(num_wrong))
print(output_frame.to_string(index=False))
# Out:
# You got 1 wrong.  Keep trying!
#
#  Input 1    Input 2    Linear Combination    Activation Output   Is Correct
#        0          0                 -1000                    0          Yes
#        0          1                  -800                    0          Yes
#        1          0                  9000                    1           No
#        1          1                  9200                    1          Yes
