# %% [markdown]
# ### Bank Customer Churn
#
# ###### Objectives:
#
# Given a Bank customer, Can we build a classifier which can determine
# whether they will leave or not?

# %%
# Importing the necessary modules
import pandas as pd
import numpy as np
import os 
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('dark_background')
os.chdir('E:\\Datasets')
os.listdir()
# Out:
# ['airbnb-listings_netherlands.csv',
#  'Churn_Modelling.csv',
#  'creditcard.csv',
#  'dataexam.txt',
#  'F1',
#  'housing',
#  'Kaggle',
#  'ml-100k',
#  'model.pkl',
#  'nlp',
#  'PythonDA',
#  'Sensor',
#  'WideWorldImporters-Full.bak']

# %%
path = os.path.join(os.getcwd(),os.listdir()[1])
path
# Out:
# 'E:\\Datasets\\Churn_Modelling.csv'

# %%
data = pd.read_csv(path,header=0) # loading the comma separated file.

# %%
data.info() # checking the data type, total entries
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# RowNumber          10000 non-null int64
# CustomerId         10000 non-null int64
# Surname            10000 non-null object
# CreditScore        10000 non-null int64
# Geography          10000 non-null object
# Gender             10000 non-null object
# Age                10000 non-null int64
# Tenure             10000 non-null int64
# Balance            10000 non-null float64
# NumOfProducts      10000 non-null int64
# HasCrCard          10000 non-null int64
# IsActiveMember     10000 non-null int64
# EstimatedSalary    10000 non-null float64
# Exited             10000 non-null int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
data.head() # displaying the first 5 records to inspect the data.
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# We can remove row number, customerid and surname from the observation as it won't help us in getting insights about the data further.

# %%
data.drop(['RowNumber','CustomerId','Surname'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-58770d668ed2> in <module>
# ----> 1 data.drop(['RowNumber','CustomerId','Surname'],axis=1,inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3944                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3945             else:
# -> 3946                 new_axis = axis.drop(labels, errors=errors)
#    3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5338         if mask.any():
#    5339             if errors != "ignore":
# -> 5340                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5341             indexer = indexer[~mask]
#    5342         return self.delete(indexer)
#
# KeyError: "['RowNumber' 'CustomerId' 'Surname'] not found in axis"

# %%
data.isnull().any()
# Out:
# CreditScore        False
# Geography          False
# Gender             False
# Age                False
# Tenure             False
# Balance            False
# NumOfProducts      False
# HasCrCard          False
# IsActiveMember     False
# EstimatedSalary    False
# Exited             False
# dtype: bool

# %% [markdown]
# The data appears to be clean with no null values we need to take care of.
# Before we examine the numerical values, lets get information on the categorical variables.
# Geography and the Gender

# %%
data['Geography'].value_counts().plot.barh() ; plt.show()

# %%
data['Gender'].value_counts().plot.barh() ; plt.show()

# %% [markdown]
# Let's see which country has the higest,lowest and average values with respect to credit score and Age

# %%
data.groupby(['Geography'])[['CreditScore','Age']].agg(['count'])
# Out:
#           CreditScore   Age
#                 count count
# Geography
# France           5014  5014
# Germany          2509  2509
# Spain            2477  2477

# %%
data.Balance = data.Balance.replace(0.00,data.Balance.median())

# %% [markdown]
# It seems all the countries have the same min and max values with slight differences in their respective mean.
#
# Lets plot a histogram to find the distribution of the data for the continous variables.

# %%
val = pd.cut(data.EstimatedSalary,bins=8)

# %%
data['est_salary_binned'] = val.values.codes

# %%
val.values.categories

# %%
continous = ['Age','Balance','CreditScore','EstimatedSalary','est_salary_binned']
data[continous].hist(bins=20,figsize=(15,10))
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
# CreditScore          10000 non-null int64
# Geography            10000 non-null object
# Gender               10000 non-null object
# Age                  10000 non-null int64
# Tenure               10000 non-null int64
# Balance              10000 non-null float64
# NumOfProducts        10000 non-null int64
# HasCrCard            10000 non-null int64
# IsActiveMember       10000 non-null int64
# EstimatedSalary      10000 non-null float64
# Exited               10000 non-null int64
# est_salary_binned    10000 non-null int8
# dtypes: float64(2), int64(7), int8(1), object(2)
# memory usage: 869.3+ KB

# %% [markdown]
#     1.Age is close to a normal distribution with data skewed to the right.
#
#     2.Balance: Expect for customers whose balance is 0, data is normally distributed.
#
#     3.Credict score is mostly left skewed with most of them in the range of 620 to 700 credits and close to 400 customers have highest credit score.
#
#     4.Estimated salary is pretty much balanced and close to uniform distribution.

# %%
discrete = ['Geography','Gender', 'Tenure', 'NumOfProducts', 'HasCrCard','IsActiveMember', 'Exited']
plt.figure(figsize=(16,30))
for i,col in enumerate(data[discrete].columns):
    x = data[col].value_counts().index.values
    y = data[col].value_counts()
    plt.subplot(7,3,i+1)
    plt.bar(x,y,align='center')
    plt.title(col)
    plt.subplots_adjust(wspace=0.5,hspace=.5)
    plt.xlabel(f"Categories for {col}")
    plt.ylabel("value counts")

# %% [markdown]
# Clearly the response value is not balanced and we might have to balance it so that our model is not biased towards customer who have not exited.
#
# Let's check the correlation between each featues

# %%
correlation = data.corr()

# %%
round(correlation.where((correlation > 0.1) | (correlation < -0.1)),2)
# Out:
#                    CreditScore   Age  Tenure  Balance  NumOfProducts  \
# CreditScore                1.0   NaN     NaN      NaN            NaN
# Age                        NaN  1.00     NaN      NaN            NaN
# Tenure                     NaN   NaN     1.0      NaN            NaN
# Balance                    NaN   NaN     NaN     1.00          -0.14
# NumOfProducts              NaN   NaN     NaN    -0.14           1.00
# HasCrCard                  NaN   NaN     NaN      NaN            NaN
# IsActiveMember             NaN   NaN     NaN      NaN            NaN
# EstimatedSalary            NaN   NaN     NaN      NaN            NaN
# Exited                     NaN  0.29     NaN      NaN            NaN
# est_salary_binned          NaN   NaN     NaN      NaN            NaN
#
#                    HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# CreditScore              NaN             NaN              NaN     NaN
# Age                      NaN             NaN              NaN    0.29
# Tenure                   NaN             NaN              NaN     NaN
# Balance                  NaN             NaN              NaN     NaN
# NumOfProducts            NaN             NaN              NaN     NaN
# HasCrCard                1.0             NaN              NaN     NaN
# IsActiveMember           NaN            1.00              NaN   -0.16
# EstimatedSalary          NaN             NaN             1.00     NaN
# Exited                   NaN           -0.16              NaN    1.00
# est_salary_binned        NaN             NaN             0.99     NaN
#
#                    est_salary_binned
# CreditScore                      NaN
# Age                              NaN
# Tenure                           NaN
# Balance                          NaN
# NumOfProducts                    NaN
# HasCrCard                        NaN
# IsActiveMember                   NaN
# EstimatedSalary                 0.99
# Exited                           NaN
# est_salary_binned               1.00

# %% [markdown]
# We don't see any strong correlation between the features. Let's build a scatter matrix between the continous variables.

# %%
data['balance_by_age'] = data.Balance / data.Age
data['noOfProducts_by_age'] = data.NumOfProducts / data.Age
data['tenure_by_age'] = data.Tenure / data.Age
data['EstimatedSalary_by_prodcuts'] = data.EstimatedSalary / data.NumOfProducts
data['credit_score_by_age'] = data.CreditScore / data.Age
data['salary_by_credit_score'] =  data.EstimatedSalary /data.CreditScore

# %%
from pandas.plotting import scatter_matrix
# columns = ['Age','Balance','EstimatedSalary','est_salary_binned',
#            'balance_by_age','noOfProducts_by_age','tenure_by_age','EstimatedSalary_by_prodcuts']
columns = ['Age','Balance',
           'balance_by_age','noOfProducts_by_age','tenure_by_age','EstimatedSalary_by_prodcuts',
          'credit_score_by_age','salary_by_credit_score']
scatter_matrix(data[columns],figsize=(10,10),alpha=0.3)
plt.show()

# %% [markdown]
# the estimated salary and Balance are uniformly distributed around 1M and 1.5M
#
# ##### Data Preprocessing
# We need to take care of the categorical variables. Let's encode the column Gender to 1 and 0 as there is only 2 values

# %%
data['Gender'] = data['Gender'].map({'Male':1,'Female':0})
data['Gender'].value_counts()
# Out:
# 1    5457
# 0    4543
# Name: Gender, dtype: int64

# %%
# creating a separate data frame to keep a copy of the data from Original data
numerical = data.select_dtypes(include=np.number)
categorical = data.select_dtypes(include=np.object)

# %%
categorical_dummies = pd.get_dummies(categorical).astype('uint8')
categorical_dummies.head()
# Out:
#    Geography_France  Geography_Germany  Geography_Spain
# 0                 1                  0                0
# 1                 0                  0                1
# 2                 1                  0                0
# 3                 1                  0                0
# 4                 0                  0                1

# %%
numerical = pd.concat([numerical,categorical_dummies],axis=1)
numerical.head()
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619       0   42       2   97198.54              1          1
# 1          608       0   41       1   83807.86              1          0
# 2          502       0   42       8  159660.80              3          1
# 3          699       0   39       1   97198.54              2          0
# 4          850       0   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  est_salary_binned  balance_by_age  \
# 0               1        101348.88       1                  4     2314.250952
# 1               1        112542.58       0                  4     2044.094146
# 2               0        113931.57       1                  4     3801.447619
# 3               0         93826.63       0                  3     2492.270256
# 4               1         79084.10       0                  3     2918.856279
#
#    noOfProducts_by_age  tenure_by_age  EstimatedSalary_by_prodcuts  \
# 0             0.023810       0.047619                   101348.880
# 1             0.024390       0.024390                   112542.580
# 2             0.071429       0.190476                    37977.190
# 3             0.051282       0.025641                    46913.315
# 4             0.023256       0.046512                    79084.100
#
#    credit_score_by_age  salary_by_credit_score  Geography_France  \
# 0            14.738095              163.730016                 1
# 1            14.829268              185.102928                 0
# 2            11.952381              226.955319                 1
# 3            17.923077              134.229800                 1
# 4            19.767442               93.040118                 0
#
#    Geography_Germany  Geography_Spain
# 0                  0                0
# 1                  0                1
# 2                  0                0
# 3                  0                0
# 4                  0                1

# %%
corr_num = numerical.corr()

# %%
numerical.Balance = numerical.Balance.replace(0.00,numerical.Balance.median())

# %%
(corr_num.Exited.sort_values(ascending=False) < 0.1) & (corr_num.Exited.sort_values(ascending=False) > -0.1)
# Out:
# Exited                         False
# Age                            False
# Geography_Germany              False
# EstimatedSalary_by_prodcuts     True
# Balance                         True
# salary_by_credit_score          True
# est_salary_binned               True
# EstimatedSalary                 True
# HasCrCard                       True
# Tenure                          True
# CreditScore                     True
# NumOfProducts                   True
# Geography_Spain                 True
# Geography_France               False
# Gender                         False
# tenure_by_age                  False
# IsActiveMember                 False
# balance_by_age                 False
# noOfProducts_by_age            False
# credit_score_by_age            False
# Name: Exited, dtype: bool

# %%
corr_num.where((corr_num < 0.1) & (corr_num > -0.1))['Exited']
# Out:
# CreditScore                   -0.027094
# Gender                              NaN
# Age                                 NaN
# Tenure                        -0.014001
# Balance                        0.063718
# NumOfProducts                 -0.047820
# HasCrCard                     -0.007138
# IsActiveMember                      NaN
# EstimatedSalary                0.012097
# Exited                              NaN
# est_salary_binned              0.012408
# balance_by_age                      NaN
# noOfProducts_by_age                 NaN
# tenure_by_age                       NaN
# EstimatedSalary_by_prodcuts    0.078997
# credit_score_by_age                 NaN
# salary_by_credit_score         0.025513
# Geography_France                    NaN
# Geography_Germany                   NaN
# Geography_Spain               -0.052667
# Name: Exited, dtype: float64

# %%
drop_values
# Out:
#                              CreditScore    Gender       Age    Tenure  \
# CreditScore                          NaN -0.002857 -0.003965  0.000842
# Gender                         -0.002857       NaN -0.027544  0.014733
# Age                            -0.003965 -0.027544       NaN -0.009997
# Tenure                          0.000842  0.014733 -0.009997       NaN
# Balance                        -0.000010  0.020592  0.005079 -0.002011
# NumOfProducts                   0.012238 -0.021859 -0.030680  0.013444
# HasCrCard                      -0.005458  0.005766 -0.011721  0.022583
# IsActiveMember                  0.025651  0.022544  0.085472 -0.028362
# EstimatedSalary                -0.001384 -0.008112 -0.007201  0.007784
# Exited                         -0.027094       NaN       NaN -0.014001
# est_salary_binned              -0.001914 -0.008909 -0.008165  0.007348
# balance_by_age                  0.005511  0.035023       NaN  0.006838
# noOfProducts_by_age             0.015295 -0.002652       NaN  0.018385
# tenure_by_age                   0.003732  0.022781       NaN       NaN
# EstimatedSalary_by_prodcuts    -0.009300 -0.003253  0.019260 -0.004492
# credit_score_by_age                  NaN  0.021699       NaN  0.010507
# salary_by_credit_score               NaN -0.009124 -0.003954  0.006935
# Geography_France               -0.008928  0.006772 -0.039208 -0.002848
# Geography_Germany               0.005538 -0.024628  0.046897 -0.000567
# Geography_Spain                 0.004780  0.016889 -0.001685  0.003868
#
#                               Balance  NumOfProducts  HasCrCard  \
# CreditScore                 -0.000010       0.012238  -0.005458
# Gender                       0.020592      -0.021859   0.005766
# Age                          0.005079      -0.030680  -0.011721
# Tenure                      -0.002011       0.013444   0.022583
# Balance                           NaN            NaN  -0.002642
# NumOfProducts                     NaN            NaN   0.003183
# HasCrCard                   -0.002642       0.003183        NaN
# IsActiveMember              -0.016561       0.009612  -0.011866
# EstimatedSalary              0.004621       0.014204  -0.009933
# Exited                       0.063718      -0.047820  -0.007138
# est_salary_binned            0.002192       0.017242  -0.011052
# balance_by_age                    NaN      -0.073787   0.007988
# noOfProducts_by_age               NaN            NaN   0.007727
# tenure_by_age               -0.004529       0.023576   0.022574
# EstimatedSalary_by_prodcuts  0.077999            NaN  -0.010578
# credit_score_by_age         -0.004785       0.029972   0.006734
# salary_by_credit_score       0.005275       0.009932  -0.007135
# Geography_France                  NaN       0.001230   0.002467
# Geography_Germany                 NaN      -0.010419   0.010577
# Geography_Spain             -0.060350       0.009039  -0.013480
#
#                              IsActiveMember  EstimatedSalary    Exited  \
# CreditScore                        0.025651        -0.001384 -0.027094
# Gender                             0.022544        -0.008112       NaN
# Age                                0.085472        -0.007201       NaN
# Tenure                            -0.028362         0.007784 -0.014001
# Balance                           -0.016561         0.004621  0.063718
# NumOfProducts                      0.009612         0.014204 -0.047820
# HasCrCard                         -0.011866        -0.009933 -0.007138
# IsActiveMember                          NaN        -0.011421       NaN
# EstimatedSalary                   -0.011421              NaN  0.012097
# Exited                                  NaN         0.012097       NaN
# est_salary_binned                 -0.010804              NaN  0.012408
# balance_by_age                    -0.042723         0.006285       NaN
# noOfProducts_by_age               -0.021133         0.011778       NaN
# tenure_by_age                     -0.043794         0.008281       NaN
# EstimatedSalary_by_prodcuts       -0.021924              NaN  0.078997
# credit_score_by_age               -0.026943         0.004307       NaN
# salary_by_credit_score            -0.020349              NaN  0.025513
# Geography_France                   0.003317        -0.003332       NaN
# Geography_Germany                 -0.020486         0.010297       NaN
# Geography_Spain                    0.016732        -0.006482 -0.052667
#
#                              est_salary_binned  balance_by_age  \
# CreditScore                          -0.001914        0.005511
# Gender                               -0.008909        0.035023
# Age                                  -0.008165             NaN
# Tenure                                0.007348        0.006838
# Balance                               0.002192             NaN
# NumOfProducts                         0.017242       -0.073787
# HasCrCard                            -0.011052        0.007988
# IsActiveMember                       -0.010804       -0.042723
# EstimatedSalary                            NaN        0.006285
# Exited                                0.012408             NaN
# est_salary_binned                          NaN        0.006004
# balance_by_age                        0.006004             NaN
# noOfProducts_by_age                   0.014906             NaN
# tenure_by_age                         0.008903             NaN
# EstimatedSalary_by_prodcuts                NaN        0.039554
# credit_score_by_age                   0.005087             NaN
# salary_by_credit_score                     NaN        0.003838
# Geography_France                     -0.003915       -0.035182
# Geography_Germany                     0.009384        0.079768
# Geography_Spain                      -0.004890       -0.039361
#
#                              noOfProducts_by_age  tenure_by_age  \
# CreditScore                             0.015295       0.003732
# Gender                                 -0.002652       0.022781
# Age                                          NaN            NaN
# Tenure                                  0.018385            NaN
# Balance                                      NaN      -0.004529
# NumOfProducts                                NaN       0.023576
# HasCrCard                               0.007727       0.022574
# IsActiveMember                         -0.021133      -0.043794
# EstimatedSalary                         0.011778       0.008281
# Exited                                       NaN            NaN
# est_salary_binned                       0.014906       0.008903
# balance_by_age                               NaN            NaN
# noOfProducts_by_age                          NaN            NaN
# tenure_by_age                                NaN            NaN
# EstimatedSalary_by_prodcuts                  NaN      -0.013007
# credit_score_by_age                          NaN            NaN
# salary_by_credit_score                  0.006068       0.005680
# Geography_France                        0.022535       0.010019
# Geography_Germany                      -0.036907      -0.023493
# Geography_Spain                         0.010965       0.011989
#
#                              EstimatedSalary_by_prodcuts  credit_score_by_age  \
# CreditScore                                    -0.009300                  NaN
# Gender                                         -0.003253             0.021699
# Age                                             0.019260                  NaN
# Tenure                                         -0.004492             0.010507
# Balance                                         0.077999            -0.004785
# NumOfProducts                                        NaN             0.029972
# HasCrCard                                      -0.010578             0.006734
# IsActiveMember                                 -0.021924            -0.026943
# EstimatedSalary                                      NaN             0.004307
# Exited                                          0.078997                  NaN
# est_salary_binned                                    NaN             0.005087
# balance_by_age                                  0.039554                  NaN
# noOfProducts_by_age                                  NaN                  NaN
# tenure_by_age                                  -0.013007                  NaN
# EstimatedSalary_by_prodcuts                          NaN            -0.021776
# credit_score_by_age                            -0.021776                  NaN
# salary_by_credit_score                               NaN                  NaN
# Geography_France                               -0.010284             0.030502
# Geography_Germany                               0.023258            -0.037446
# Geography_Spain                                -0.011447             0.002277
#
#                              salary_by_credit_score  Geography_France  \
# CreditScore                                     NaN         -0.008928
# Gender                                    -0.009124          0.006772
# Age                                       -0.003954         -0.039208
# Tenure                                     0.006935         -0.002848
# Balance                                    0.005275               NaN
# NumOfProducts                              0.009932          0.001230
# HasCrCard                                 -0.007135          0.002467
# IsActiveMember                            -0.020349          0.003317
# EstimatedSalary                                 NaN         -0.003332
# Exited                                     0.025513               NaN
# est_salary_binned                               NaN         -0.003915
# balance_by_age                             0.003838         -0.035182
# noOfProducts_by_age                        0.006068          0.022535
# tenure_by_age                              0.005680          0.010019
# EstimatedSalary_by_prodcuts                     NaN         -0.010284
# credit_score_by_age                             NaN          0.030502
# salary_by_credit_score                          NaN         -0.001963
# Geography_France                          -0.001963               NaN
# Geography_Germany                          0.009586               NaN
# Geography_Spain                           -0.007354               NaN
#
#                              Geography_Germany  Geography_Spain
# CreditScore                           0.005538         0.004780
# Gender                               -0.024628         0.016889
# Age                                   0.046897        -0.001685
# Tenure                               -0.000567         0.003868
# Balance                                    NaN        -0.060350
# NumOfProducts                        -0.010419         0.009039
# HasCrCard                             0.010577        -0.013480
# IsActiveMember                       -0.020486         0.016732
# EstimatedSalary                       0.010297        -0.006482
# Exited                                     NaN        -0.052667
# est_salary_binned                     0.009384        -0.004890
# balance_by_age                        0.079768        -0.039361
# noOfProducts_by_age                  -0.036907         0.010965
# tenure_by_age                        -0.023493         0.011989
# EstimatedSalary_by_prodcuts           0.023258        -0.011447
# credit_score_by_age                  -0.037446         0.002277
# salary_by_credit_score                0.009586        -0.007354
# Geography_France                           NaN              NaN
# Geography_Germany                          NaN              NaN
# Geography_Spain                            NaN              NaN

# %%
numerical.drop('EstimatedSalary',axis=1,inplace=True)

# %%
numerical
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619       0   42       2   97198.54              1          1
# 1             608       0   41       1   83807.86              1          0
# 2             502       0   42       8  159660.80              3          1
# 3             699       0   39       1   97198.54              2          0
# 4             850       0   43       2  125510.82              1          1
# ...           ...     ...  ...     ...        ...            ...        ...
# 9995          771       1   39       5   97198.54              2          1
# 9996          516       1   35      10   57369.61              1          1
# 9997          709       0   36       7   97198.54              1          0
# 9998          772       1   42       3   75075.31              2          1
# 9999          792       0   28       4  130142.79              1          1
#
#       IsActiveMember  Exited  est_salary_binned  balance_by_age  \
# 0                  1       1                  4     2314.250952
# 1                  1       0                  4     2044.094146
# 2                  0       1                  4     3801.447619
# 3                  0       0                  3     2492.270256
# 4                  1       0                  3     2918.856279
# ...              ...     ...                ...             ...
# 9995               0       0                  3     2492.270256
# 9996               1       0                  4     1639.131714
# 9997               1       1                  1     2699.959444
# 9998               0       1                  3     1787.507381
# 9999               0       0                  1     4647.956786
#
#       noOfProducts_by_age  tenure_by_age  EstimatedSalary_by_prodcuts  \
# 0                0.023810       0.047619                   101348.880
# 1                0.024390       0.024390                   112542.580
# 2                0.071429       0.190476                    37977.190
# 3                0.051282       0.025641                    46913.315
# 4                0.023256       0.046512                    79084.100
# ...                   ...            ...                          ...
# 9995             0.051282       0.128205                    48135.320
# 9996             0.028571       0.285714                   101699.770
# 9997             0.027778       0.194444                    42085.580
# 9998             0.047619       0.071429                    46444.260
# 9999             0.035714       0.142857                    38190.780
#
#       credit_score_by_age  salary_by_credit_score  Geography_France  \
# 0               14.738095              163.730016                 1
# 1               14.829268              185.102928                 0
# 2               11.952381              226.955319                 1
# 3               17.923077              134.229800                 1
# 4               19.767442               93.040118                 0
# ...                   ...                     ...               ...
# 9995            19.769231              124.864643                 1
# 9996            14.742857              197.092578                 1
# 9997            19.694444               59.359069                 1
# 9998            18.380952              120.321917                 0
# 9999            28.285714               48.220682                 1
#
#       Geography_Germany  Geography_Spain
# 0                     0                0
# 1                     0                1
# 2                     0                0
# 3                     0                0
# 4                     0                1
# ...                 ...              ...
# 9995                  0                0
# 9996                  0                0
# 9997                  0                0
# 9998                  1                0
# 9999                  0                0
#
# [10000 rows x 19 columns]

# %% [markdown]
# Let's drop the response variable from our data set as its the one we need to predict

# %%
response_variable = numerical['Exited'].copy().astype('uint8').values
numerical = numerical.drop('Exited',axis=1)

# %% [markdown]
# Let's concat the categorical dummies and split between train and test

# %%
numerical = pd.concat([numerical,categorical_dummies],axis=1)
numerical.head(2)
# Out:
#    CreditScore  Gender  Age  Tenure   Balance  NumOfProducts  HasCrCard  \
# 0          619       0   42       2  97198.54              1          1
# 1          608       0   41       1  83807.86              1          0
#
#    IsActiveMember  est_salary_binned  balance_by_age  ...  tenure_by_age  \
# 0               1                  4     2314.250952  ...       0.047619
# 1               1                  4     2044.094146  ...       0.024390
#
#    EstimatedSalary_by_prodcuts  credit_score_by_age  salary_by_credit_score  \
# 0                    101348.88            14.738095              163.730016
# 1                    112542.58            14.829268              185.102928
#
#    Geography_France  Geography_Germany  Geography_Spain  Geography_France  \
# 0                 1                  0                0                 1
# 1                 0                  0                1                 0
#
#    Geography_Germany  Geography_Spain
# 0                  0                0
# 1                  0                1
#
# [2 rows x 21 columns]

# %% [markdown]
# Now that we have converted the data to numerical values we would need to split the data into train test sets

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(numerical,response_variable,test_size=0.2,
                                                 random_state=42)

# %% [markdown]
# We need to scale the data for the algorithm to converge faster and also the classifier we are going is sensitive to scaling.

# %%
from sklearn.preprocessing import StandardScaler
std_sclr = StandardScaler()
x_train = std_sclr.fit_transform(x_train)
x_test = std_sclr.transform(x_test)

# %% [markdown]
# Lets train the model and predict using SDGClassifier

# %%
from sklearn.linear_model import SGDClassifier

# %%
sgd_clsr = SGDClassifier(random_state=42,max_iter=1000)
sgd_clsr.fit(x_train,y_train)
# Out:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#               early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#               l1_ratio=0.15, learning_rate='optimal', loss='hinge',
#               max_iter=1000, n_iter_no_change=5, n_jobs=None, penalty='l2',
#               power_t=0.5, random_state=42, shuffle=True, tol=0.001,
#               validation_fraction=0.1, verbose=0, warm_start=False)

# %%
y_pred = sgd_clsr.predict(x_test)

# %%
# accuracy 
sum(y_test == y_pred) / len(y_test)
# Out:
# 0.816

# %% [markdown]
# Our model gives 80% accuracy.
#
# Now lets import the sklearn cross validation library and do cross validation to see if we can get different accuracy with different train and validation set

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(sgd_clsr,x_train,y_train,cv=5,scoring='accuracy')

# %% [markdown]
# On an average we are still getting the accuracy closer to 80%.
# Lets try to perfrom stratified sampling with cross validation.

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.base import clone
skfolds = StratifiedKFold(n_splits=5,random_state=42)

# %%
for train_index,test_index in skfolds.split(x_train,y_train):
    clone_clf = clone(sgd_clsr)
    x_train_folds,y_train_folds = x_train[train_index],y_train[train_index]
    x_test_fold,y_test_fold  = x_train[test_index],y_train[test_index]
    
    clone_clf.fit(x_train_folds,y_train_folds)
    y_pred_fold = clone_clf.predict(x_test_fold)
    n_correct = sum(y_pred_fold == y_test_fold) / len(y_test_fold) 
    print(n_correct)

# %% [markdown]
# Since the response variable data is not balanced the model provides an accuracy towards a naive prediction towards customers who will not exit.
#
# Lets test the model by creating a dumb classifier

# %%
from sklearn.base import BaseEstimator

class NotExited(BaseEstimator):
    def fit(self,X,y=None):
        pass
    def predict(self,X):
        return np.zeros((len(X),1),dtype=bool)

# %%
notexit = NotExited()
cross_val_score(notexit,x_train_folds,y_train_folds,cv=5,scoring='accuracy')

# %% [markdown]
# Our dumb classifier outputs 80% accuracy which is pretty much close to the SDGClassifier. Hence we cannot rely on the accuracy score and we also would need to balance the class in order to get  better prediction.
#
# Lets balance the data by oversampling the minority class

# %%
from imblearn.over_sampling import SMOTE
balance = SMOTE(random_state=42)

x_train_over,y_train_over = balance.fit_sample(x_train_folds,y_train_folds)
print(x_train_over.shape,y_train_over.shape)

# %%
print(f"customer NotExited value {sum(y_train_over==0)}")
print(f"customer Exited value {sum(y_train_over==1)}")

# %% [markdown]
# Now that our data is up sampled we can now apply the SDG to get the score.

# %%
sgd_clsr.fit(x_train_over,y_train_over)

# %%
y_pred = sgd_clsr.predict(x_test_fold)

# %%
sum(y_test_fold == y_pred) / len(y_test_fold)

# %% [markdown]
# Looks like after oversampling we get an accuracy of 72%, Let's try to see what we get for recall and precision

# %%
from sklearn.model_selection import cross_val_predict
y_train_pred = cross_val_predict(sgd_clsr,x_train_over,y_train_over,cv=5)
np.unique(y_train_pred,return_counts=True)

# %%
from sklearn.metrics import confusion_matrix
cnf_matrix = confusion_matrix(y_train_over,y_train_pred)

# using seaborn plotting the confusion matrix. 
sns.heatmap(cnf_matrix, annot=True,fmt='.0f')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# It seems we might have to increase the recall to ensure we reduce the number of false negatives, where we would need to let certain few prediction as false positives. There is a trade off.

# %%
from sklearn.metrics import precision_score,recall_score,f1_score,roc_auc_score

# %%
precision_score(y_train_over,y_train_pred)

# %%
recall_score(y_train_over,y_train_pred)

# %%
f1_score(y_train_over,y_train_pred)

# %%
y_scores = cross_val_predict(sgd_clsr,x_train_over,y_train_over,cv=3,method='decision_function')

# %%
roc_auc_score(y_train_over,y_scores)

# %% [markdown]
# #### Hyperparameter search
# Let's fine tune the model to see if we can tune the hyperparamters using GridSearch

# %%
from sklearn.model_selection import GridSearchCV

# %%
sgd_clsr.get_params().keys()

# %%
param_grid = {'alpha':10.0**-np.arange(1,7),
              'class_weight':['balanced',None],
              'penalty':[None,'l1','l2','elasticnet'],
              'n_iter_no_change':np.arange(5,10)}


scoring = ['f1','accuracy','precision','recall','roc_auc']

# %%
grid_search = GridSearchCV(sgd_clsr,param_grid,cv=5,n_jobs=-1,
                           scoring=scoring,refit='f1',
                          return_train_score=True)

# %%
# %time grid_search.fit(x_train_over,y_train_over)

# %%
final_estimator = grid_search.best_estimator_
final_estimator

# %%
grid_search.best_estimator_

# %%
final_estimator.fit(x_train_over,y_train_over)
final_prediction = final_estimator.predict(x_test)
sum(y_test == final_prediction) / len(y_test)

# %% [markdown]
# #### Conclusion
#
# 1) With this Model we are getting a lower accuracy, we can try out different ensemble models which could perform well and give better prediction. However, we may not get better accuracy as the model might not generalize well due to synthetic data created. <br>
# 2) We could try RandomizedSearchCV and search the hyperparameter space for the best estimator. <br>
# 3) Refactor code and make resuable functions. <br>
#
# <br>
# Even if we get the highest feasible accuracy there will be a trade off between true positive rate (recall) and false positive rate. <br>
# <br>
# Example. Lets say if onboarding new customers is more costlier than retaining existing customers. Then we want to capture all the True positives and have a higher recall rate, so that bank can decide to give certain discounts to retain the customers.

# %%
from sklearn.ensemble import RandomForestClassifier
rforest_clsr = RandomForestClassifier(random_state=42,n_estimators=10)
rforest_clsr.fit(x_train_over,y_train_over)
y_pred_forest = rforest_clsr.predict(x_test)
sum(y_test == y_pred_forest) / len(y_test)

# %%
cross_val_score(rforest_clsr,x_train_over,y_train_over,cv=5,scoring='f1')

# %%
rforest_clsr.get_params

# %%
param_grid = {'n_estimators':np.arange(10,20),
#               'max_depth':np.arange(2,10),
              'max_features':np.arange(2,13),}


scoring = ['f1','accuracy','precision','recall','roc_auc']

grid_search = GridSearchCV(rforest_clsr,param_grid,cv=5,n_jobs=-1,
                           scoring=scoring,refit='f1',
                          return_train_score=True)

# %%
# %time grid_search.fit(x_train_over,y_train_over)

# %%
grid_search.best_params_
grid_search.best_estimator_.feature_importances_.round(2)

# %%
grid_search.best_estimator_.fit(x_train_over,y_train_over)
pred = grid_search.best_estimator_.predict(x_test)
sum(y_test == pred) / len(y_test)

# %%
cross_val_score(grid_search.best_estimator_,x_train_over,y_train_over,cv=10,scoring='recall')
